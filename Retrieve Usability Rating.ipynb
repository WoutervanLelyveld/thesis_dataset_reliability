# %% [markdown]
# This is a experimental piece that was used for trying to retrieve the UsabilityRating from each dataset as this is not provided by the API.

# %% [markdown]
# IMPORTS

# %%
import pandas as pd

# %%
# %store -r kaggle_datasets_versions_users_data

# %%
kaggle_datasets_versions_users_data
# Out:
#            Id_x  CreatorUserId_x  OwnerUserId  OwnerOrganizationId  \
# 0             6                1          NaN                 12.0
# 1             6                1          NaN                 12.0
# 2            23           514856          NaN                  4.0
# 3            23           514856          NaN                  4.0
# 4            24              993        993.0                  NaN
# ...         ...              ...          ...                  ...
# 613036  2270044          5382272    5382272.0                  NaN
# 613037  2270044          5382272    5382272.0                  NaN
# 613038  2270048          8064850    8064850.0                  NaN
# 613039  2270272         10165404   10165404.0                  NaN
# 613040  2270411          6210092    6210092.0                  NaN
#
#         CurrentDatasetVersionId  CurrentDatasourceVersionId  ForumId  Type  \
# 0                        2158.0                      2158.0      762     2
# 1                        2158.0                      2158.0      762     2
# 2                        2151.0                      2151.0     1035     2
# 3                        2151.0                      2151.0     1035     2
# 4                      792987.0                    814776.0     1078     2
# ...                         ...                         ...      ...   ...
# 613036                3809034.0                   3863761.0  2296548     2
# 613037                3809034.0                   3863761.0  2296548     2
# 613038                3809014.0                   3863741.0  2296553     2
# 613039                3809564.0                   3864292.0  2296779     2
# 613040                3809991.0                   3864722.0  2296919     2
#
#              CreationDate_x LastActivityDate  ...  TotalUncompressedBytes  \
# 0       07/18/2015 00:51:12       2018-02-05  ...            4.203827e+09
# 1       07/18/2015 00:51:12       2018-02-05  ...                     NaN
# 2       01/28/2016 06:30:59       2018-02-06  ...            2.042308e+09
# 3       01/28/2016 06:30:59       2018-02-06  ...                     NaN
# 4       02/19/2016 06:37:00       2018-02-06  ...                     NaN
# ...                     ...              ...  ...                     ...
# 613036  06/15/2022 18:34:26       2022-06-15  ...            0.000000e+00
# 613037  06/15/2022 18:34:26       2022-06-15  ...            0.000000e+00
# 613038  06/15/2022 18:36:14       2022-06-15  ...            0.000000e+00
# 613039  06/15/2022 21:16:42       2022-06-15  ...            0.000000e+00
# 613040  06/15/2022 23:41:07       2022-06-15  ...            0.000000e+00
#
#                                   Kaggle_Location  CreationDate  \
# 0       kaggleteam/2013-american-community-survey    2015-07-18
# 1       kaggleteam/2013-american-community-survey    2015-07-18
# 2                                             NaN    2016-01-28
# 3                                             NaN    2016-01-28
# 4                      benhamner/2016-us-election    2016-02-19
# ...                                           ...           ...
# 613036             rahulshelke98/full-raw-dataset    2022-06-15
# 613037             rahulshelke98/full-raw-dataset    2022-06-15
# 613038   harshsingh2209/ethereum-pricing-20202022    2022-06-15
# 613039               weavrk/average-iq-by-country    2022-06-15
# 613040                uplus26e7/uspppm-037-models    2022-06-15
#
#         Diff_LastActivityDate_CreationDate  \
# 0                                      933
# 1                                      933
# 2                                      740
# 3                                      740
# 4                                      718
# ...                                    ...
# 613036                                   0
# 613037                                   0
# 613038                                   0
# 613039                                   0
# 613040                                   0
#
#         ActivityStatus_LastActivity_CreationDate Diff_LastActivityDate_Today  \
# 0                                              4                        1592
# 1                                              4                        1592
# 2                                              4                        1591
# 3                                              4                        1591
# 4                                              4                        1591
# ...                                          ...                         ...
# 613036                                         1                           1
# 613037                                         1                           1
# 613038                                         1                           1
# 613039                                         1                           1
# 613040                                         1                           1
#
#        LastActivity Bool_Description  Bool_Subtitle  Description_Length
# 0                 3                1              1                3295
# 1                 3                1              1                3295
# 2                 3                1              1                 964
# 3                 3                1              1                 964
# 4                 3                1              1                2644
# ...             ...              ...            ...                 ...
# 613036            1                0              0                   0
# 613037            1                0              0                   0
# 613038            1                1              1                 509
# 613039            1                1              0                  81
# 613040            1                0              0                   0
#
# [613041 rows x 42 columns]

# %% [markdown]
# Make the location of the datasets searchable for the API (to retrieve Usability Rating)

# %%
kaggle_datasets_versions_users_data['Kaggle_Location'] = kaggle_datasets_versions_users_data['UserName'] + "/" + \
                                                         kaggle_datasets_versions_users_data['Slug']
